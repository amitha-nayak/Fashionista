# %%
#Todo
#figure out how tags are passed here and how to append for the search on each website
#display links or open links in diff tabs

# %%
import os,json

# %%
label_description_path=r'C:\Users\91948\proj\label_descriptions.json'

# %%
# %%time
with open(label_description_path, 'r') as file:
    label_desc = json.load(file)
# Out:
# Wall time: 968 µs

# %%
for i in label_desc['categories']:
    print(i['name'])
#label_desc['categories'][0]["name"]
# Out:
# shirt, blouse
# top, t-shirt, sweatshirt
# sweater
# cardigan
# jacket
# vest
# pants
# shorts
# skirt
# coat
# dress
# jumpsuit
# cape
# glasses
# hat
# headband, head covering, hair accessory
# tie
# glove
# watch
# belt
# leg warmer
# tights, stockings
# sock
# shoe
# bag, wallet
# scarf
# umbrella
# hood
# collar
# lapel
# epaulette
# sleeve
# pocket
# neckline
# buckle
# zipper
# applique
# bead
# bow
# flower
# fringe
# ribbon
# rivet
# ruffle
# sequin
# tassel

# %%
#!pip install selenium

# %%
# from bs4 import BeautifulSoup
# import requests
# URL = "https://www.flipkart.com/"
# r = requests.get(URL)
# #source=requests.get('https://open.spotify.com/search/sad/playlists').text
# soup=BeautifulSoup(r.text,"lxml")
# #print(r.content)
# print(soup)

# %%
#imp
# import requests, json
# from bs4 import BeautifulSoup

# headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

# s = requests.Session()
# res = s.get("https://www.myntra.com/shirt?p=1&plaEnabled=false", headers=headers, verify=False)

# soup = BeautifulSoup(res.text,"html.parser")
# print(soup)

# %% [markdown]
# # **Website 1**

# %%
#imp,website 1
from requests_html import HTMLSession
import json
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

s = HTMLSession()
res = s.get("https://www.myntra.com/high-tops?p=1&plaEnabled=false", headers=headers, verify=False)

soup = BeautifulSoup(res.text,"html.parser")
print(soup.html)
# Out:
# C:\Users\91948\anaconda3\envs\myenv\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.myntra.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...

# %%
#soup

# %%
#!pip install requests-html

# %%
# val2=soup.find_all('script')
# b=0
# for i in val2[2]:
#     print(b)
#     data=json.loads(soup.find('script', type='application/ld+json').text)
#     b+=1

# %%
# val=soup.find_all('script',class_='row-base')
# print(val)

# %%
#imp
val=json.loads(soup.find_all('script', type='application/ld+json')[1].string)
val
#val['itemListElement']
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'ItemList',
#  'itemListElement': [{'@type': 'ListItem',
#    'position': 1,
#    'url': 'https://www.myntra.com/tops/besiva/besiva-women-pack-of-2-burgundy--black-solid-regular-high-neck-tops/13089578/buy',
#    'name': 'Besiva Women Pack Of 2 Burgundy & Black Solid Regular High-Neck Tops'},
#   {'@type': 'ListItem',
#    'position': 2,
#    'url': 'https://www.myntra.com/tops/sassafras/sassafras-women-black-high-neck-cropped-top/12221932/buy',
#    'name': 'SASSAFRAS Women Black High Neck Cropped Top'},
#   {'@type': 'ListItem',
#    'position': 3,
#    'url': 'https://www.myntra.com/tops/sassafras/sassafras-women-white-solid-high-neck-top/12221944/buy',
#    'name': 'SASSAFRAS Women White Solid High-Neck Top'},
#   {'@type': 'ListItem',
#    'position': 4,
#    'url': 'https://www.myntra.com/tops/sassafras/sassafras-fuchsia-pink-ribbed-high-neck-fitted-crop-top/13843152/buy',
# ...

# %%
#res.html.render()

# %%
#import webbrowser
#for i in playlist_names[7:13]:
#    webbrowser.open('https://soundcloud.com'+i)

# %%
# from selenium import webdriver
# import urllib.request
# import os
# import json

# %%
# driver = webdriver.Chrome(executable_path='C:/Users/91948/chromedriver.exe')
# driver.get('https://www.myntra.com/')
# driver.find_element_by_class_name('desktop-searchBar').send_keys(search_string)
# driver.find_element_by_class_name('desktop-submit').click()

# %% [markdown]
# # **Website 2**

# %%
from requests_html import HTMLSession
import json
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

s = HTMLSession()
res = s.get("https://www2.hm.com/en_in/search-results.html?q=high-tops", headers=headers, verify=False)

soup = BeautifulSoup(res.text,"lxml")
print(soup.html)
# Out:
# C:\Users\91948\anaconda3\envs\myenv\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www2.hm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <html class="no-js en-in" lang="en-IN">
# <head>
# ...

# %%
print(soup.find_all('a', attrs={'class': 'item-link'}))
# Out:
# [<a class="item-link" href="/en_in/productpage.0975848004.html" title="Zip-top sweatshirt">
# <img alt="Zip-top sweatshirt" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/65/c8/65c83d8b305f00ecae59cb81fa580c563f134ba1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" data-alttext="Zip-top sweatshirtModel" data-src="//lp2.hm.com/hmgoepprod?set=source[/74/8e/748e53ed78be9733d43fb83ab9706ff7c5a1c3b1.jpg],origin[dam],category[ladies_basics_tops_longsleeve],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/74/8e/748e53ed78be9733d43fb83ab9706ff7c5a1c3b1.jpg],origin[dam],category[ladies_basics_tops_longsleeve],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# ...

# %%
for item in soup.select('.hm-product-item'):
	try:
		print('----------------------------------------')
		print(item.select('.item-image')[0]['data-altimage'])
		print(item.select('.item-image')[0]['data-alttext'])
		print(item.select('.item-price')[0].get_text().strip())
		for swatch in item.select('.swatch'):
			print(swatch.get_text().strip())
	except Exception as e:
		#raise e
		print('')
# Out:
# ----------------------------------------
# //lp2.hm.com/hmgoepprod?set=source[/65/c8/65c83d8b305f00ecae59cb81fa580c563f134ba1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/style]
# Zip-top sweatshirtModel
# Rs.1,299
# Light pink
# Black
# White
# Dark green
# ----------------------------------------
# //lp2.hm.com/hmgoepprod?set=source[/05/2c/052c195c62b1df2b27e0635d0685972796e587a1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/style]
# Zip-top sweatshirtModel
# Rs.1,299
# Black
# White
# Dark green
# Light pink
# ----------------------------------------
# //lp2.hm.com/hmgoepprod?set=source[/23/76/2376858de87c1820c4902cd3f722c293f28e5cfb.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/style]
# Zip-top sweatshirtModel
# Rs.1,299
# White
# Black
# Dark green
# Light pink
# ----------------------------------------
# ...

# %%
for item in soup.select('.hm-product-item'):
    print(item.select('.item-link')[0]['href'])
    print(item.select('.item-image')[0]['data-alttext'])
# Out:
# /en_in/productpage.0975848004.html
# Zip-top sweatshirtModel
# /en_in/productpage.0975848001.html
# Zip-top sweatshirtModel
# /en_in/productpage.0975848002.html
# Zip-top sweatshirtModel
# /en_in/productpage.0975848009.html
# Zip-top sweatshirtModel
# /en_in/productpage.0983486004.html
# Ribbed pyjamasModel
# /en_in/productpage.0988853002.html
# High-collar faux shearling topModel
# /en_in/productpage.1014107002.html
# 2-piece faux shearling setModel
# /en_in/productpage.1014107001.html
# 2-piece faux shearling setModel
# /en_in/productpage.0975848003.html
# Zip-top sweatshirtModel
# /en_in/productpage.0983486006.html
# Ribbed pyjamasModel
# /en_in/productpage.0971070010.html
# Printed hoodieModel
# /en_in/productpage.1012679002.html
# 2-piece ribbed cotton setModel
# /en_in/productpage.0995416001.html
# MAMA Cotton jersey pyjamasModel
# /en_in/productpage.1012679001.html
# 2-piece ribbed cotton setModel
# /en_in/productpage.0983486003.html
# Ribbed pyjamasModel

# %% [markdown]
# # **Website 3**

# %%
from requests_html import HTMLSession
import json
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

s = HTMLSession()
res = s.get("https://www.ajio.com/search/?text=half%20sleeve%20shirts", headers=headers, verify=False)

soup = BeautifulSoup(res.text,"html.parser")
print(soup.html)
# Out:
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection">
# <meta charset="utf-8">
# <meta content="mst3EDdpHbIKH409fDtfXk-wS6DAbcyLv-BXDg55gfo" name="google-site-verification"/>
# <meta content="no-transform" http-equiv="Cache-control"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport">
# <meta content="" name="author"/>
# <meta content="website" name="og:type"/>
# <meta content="Ajio.com" name="og:site_name"/>
# <meta content="233163173739076" name="fb:app_id"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@AJIOLife" name="twitter:site"/>
# <meta content="Best Offers on Half%20sleeve%20shirts - Upto 20-71% off Sale - Original Products, Fastest Delivery, No additional taxes, COD &amp; Exchange/Return. Buy now!" name="description"/>
# ...

# %%
from requests_html import HTMLSession
import json
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

s = HTMLSession()
res = s.get("https://www.ajio.com/search/?text=black%20joggers", headers=headers, verify=False)

soup = BeautifulSoup(res.text,"lxml")
print(soup.html)
# Out:
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta charset="utf-8"/>
# <meta content="mst3EDdpHbIKH409fDtfXk-wS6DAbcyLv-BXDg55gfo" name="google-site-verification"/>
# <meta content="no-transform" http-equiv="Cache-control"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="" name="author"/>
# <meta content="website" name="og:type"/>
# <meta content="Ajio.com" name="og:site_name"/>
# <meta content="233163173739076" name="fb:app_id"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@AJIOLife" name="twitter:site"/>
# <meta content="Best Offers on Black%20joggers - Upto 20-71% off Sale - Original Products, Fastest Delivery, No additional taxes, COD &amp; Exchange/Return. Buy now!" name="description"/>
# ...

# %%
val=json.loads(soup.find_all('script', type='application/ld+json')[2].string)

# %%
val
#val['itemListElement']
# Out:
# {'@context': 'http://schema.org',
#  '@type': 'ItemList',
#  'url': 'http://www.ajio.com/search/? text=half%20sleeve%20shirts',
#  'numberOfItems': '287',
#  'itemListElement': [{'@type': 'ListItem',
#    'name': 'YOONOY Half Sleeves Slim Fit Shirt',
#    'image': 'https://assets.ajio.com/medias/sys_master/root/20210511/Tes7/6099b479aeb269a9e3ba5e6a/-286Wx359H-462405461-black-MODEL.jpg',
#    'url': 'https://www.ajio.com/yoonoy-half-sleeves-slim-fit-shirt/p/462405461_black',
#    'position': 1},
#   {'@type': 'ListItem',
#    'name': 'YOONOY Spread Collar Half Sleeves  Slim Fit Shirt',
#    'image': 'https://assets.ajio.com/medias/sys_master/root/20210511/hkY1/6099b4bef997ddb31299479c/-286Wx359H-462405492-navy-MODEL.jpg',
#    'url': 'https://www.ajio.com/yoonoy-spread-collar-half-sleeves-slim-fit-shirt/p/462405492_navy',
#    'position': 2},
#   {'@type': 'ListItem',
#    'name': 'YOONOY Half Sleeves Slim Fit Shirt',
# ...
